# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %% [markdown]
# # RMSE Comparison (Basic MF, Social MF, SolRec)

# %%
#df = pd.DataFrame({'Algorithms':['Basic MF', 'SocialMF', 'SolRec'], 'RMSE':[1.178675327645319, 1.3807353991443365, 1.2103529669270774]})
#ax = df.plot.bar(x='Algorithms', y='RMSE', rot=45, palette='crest')

ax= sns.barplot(['Basic MF', 'SocialMF', 'SolRec'], [1.178675327645319, 1.3807353991443365, 1.2103529669270774], palette='rainbow')
plt.title("RMSE Comparison")
plt.ylabel('RMSE')
plt.xlabel('Algorithms')
# Out:
# Text(0.5, 0, 'Algorithms')
